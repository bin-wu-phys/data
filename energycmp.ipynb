  0.183462], [-3.67394e-16, -2., 0.000461328], [1.41421, -1.41421, 
  0.183462]])

# %%
eload = np.load('e.0.1.npz')

# %%
eload['e01']
# Out:
# array([[9.90049803e+00, 9.90049804e+00, 9.90049811e+00, 9.90049820e+00,
#         9.90049829e+00, 9.90049833e+00, 9.90049832e+00, 9.90049825e+00,
#         9.90049816e+00, 9.90049807e+00, 9.90049803e+00, 9.90049804e+00,
#         9.90049811e+00, 9.90049820e+00, 9.90049829e+00, 9.90049833e+00,
#         9.90049832e+00, 9.90049825e+00, 9.90049816e+00, 9.90049807e+00],
#        [1.66274023e+01, 1.49984630e+01, 1.07545932e+01, 5.64103381e+00,
#         2.42941843e+00, 2.27375910e+00, 2.42941841e+00, 5.64103377e+00,
#         1.07545931e+01, 1.49984630e+01, 1.66274023e+01, 1.49984630e+01,
#         1.07545932e+01, 5.64103381e+00, 2.42941843e+00, 2.27375910e+00,
#         2.42941841e+00, 5.64103377e+00, 1.07545931e+01, 1.49984630e+01],
#        [1.63527804e+01, 1.47760116e+01, 1.06489340e+01, 5.55331824e+00,
#         1.48202624e+00, 5.24073284e-01, 1.48202624e+00, 5.55331823e+00,
#         1.06489340e+01, 1.47760116e+01, 1.63527804e+01, 1.47760116e+01,
# ...

# %%
f = open('t01.dat')

# %%
f.seek(0)
math=np.array([float(e) for e in f.read().split('\n')])

# %%
f.close()

# %%
math
# Out:
# array([9.90049834e+00, 9.90049834e+00, 9.90049834e+00, 9.90049834e+00,
#        9.90049834e+00, 9.90049834e+00, 9.90049834e+00, 9.90049834e+00,
#        9.90049834e+00, 9.90049834e+00, 9.90049834e+00, 9.90049834e+00,
#        9.90049834e+00, 9.90049834e+00, 9.90049834e+00, 9.90049834e+00,
#        9.90049834e+00, 9.90049834e+00, 9.90049834e+00, 9.90049834e+00,
#        1.66274026e+01, 1.49984633e+01, 1.07545932e+01, 5.64103174e+00,
#        2.42940844e+00, 2.27375910e+00, 2.42941846e+00, 5.64102550e+00,
#        1.07546226e+01, 1.49984834e+01, 1.66274026e+01, 1.49984834e+01,
#        1.07546226e+01, 5.64102550e+00, 2.42941846e+00, 2.27375910e+00,
#        2.42940844e+00, 5.64103174e+00, 1.07545932e+01, 1.49984633e+01,
#        1.63527806e+01, 1.47760119e+01, 1.06489342e+01, 5.55331834e+00,
#        1.48202627e+00, 5.24073284e-01, 1.48202627e+00, 5.55331834e+00,
#        1.06489342e+01, 1.47760119e+01, 1.63527806e+01, 1.47760119e+01,
# ...

# %%
np.sum(np.abs(np.reshape(eload['e01'], np.prod(np.array(eload['e01'].shape)))/math-1))
# Out:
# 2.3391551890683537e-05

# %%
eload = np.load('e.2.npz')

# %%
f = open('t2.dat')

# %%
f.seek(0)
math2=np.array([float(e) for e in f.read().split('\n')])
f.close()

# %%
np.sum(np.abs(np.reshape(eload['e2'], np.prod(np.array(eload['e2'].shape)))/math2-1))
# Out:
# 2.167730230110055

# %%
np.reshape(eload['e2'], np.prod(np.array(eload['e2'].shape)))/math2-1<0.1
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
eload = np.load('e.4.npz')

# %%
f = open('t4.dat')
f.seek(0)
math4=np.array([float(e) for e in f.read().split('\n')])
f.close()

# %%
np.reshape(eload['e4'], np.prod(np.array(eload['e4'].shape)))/math4-1<0.3
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...
